# %% [markdown]
# ## Some first pointers to get started
#
# This notebook provides some first examples on how get to plotting

# %%
from ggseg_py.ggseg_py import rda2gpd
from ggseg_py.plotting_utils import plot_surface, plot_view, plot_aseg
from pathlib import Path

# %%
#load glasser

atlas_path = "../ggseg_py/atlases/glasser.rda"
gdf = rda2gpd(atlas_path, 'glasser')
gdf
# Out:
#       hemi region     side       label  \
# 1     left     V1  lateral     lh_L_V1
# 2     left    MST  lateral    lh_L_MST
# 3     left     V2  lateral     lh_L_V2
# 4     left     V3  lateral     lh_L_V3
# 5     left     V4  lateral     lh_L_V4
# ..     ...    ...      ...         ...
# 391  right  LBelt  lateral  rh_R_LBelt
# 392  right     A4  lateral     rh_R_A4
# 393  right  STSva  lateral  rh_R_STSva
# 394  right   TE1m  lateral   rh_R_TE1m
# 395  right     PI  lateral     rh_R_PI
#
#                                               geometry
# 1    MULTIPOLYGON (((292.108 69.183, 292.108 68.778...
# 2    MULTIPOLYGON (((247.982 94.258, 246.01 89.307,...
# 3    MULTIPOLYGON (((292.913 79.826, 292.173 78.667...
# 4    MULTIPOLYGON (((289.247 95.491, 289.121 94.816...
# 5    MULTIPOLYGON (((280.553 112.081, 281.263 108.4...
# ..                                                 ...
# 391  MULTIPOLYGON (((1228.978 101.057, 1228.764 97....
# 392  MULTIPOLYGON (((1214.151 107.278, 1212.826 105...
# 393  MULTIPOLYGON (((1238.779 45.537, 1236.242 44.4...
# 394  MULTIPOLYGON (((1202.985 46.351, 1202.495 45.3...
# 395  MULTIPOLYGON (((1267.962 72.213, 1267.46 69.06...
#
# [395 rows x 5 columns]

# %%
plot_surface(gdf, show_cbar=False)
# Out:
# (<Figure size 700x500 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
#now lets populate it with some data
import numpy as np

gdf['data2plot'] = np.arange(len(gdf))

plot_surface(gdf, column='data2plot', cmap='Reds', show_cbar=True)
# Out:
# (<Figure size 700x500 with 5 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
# we can also plot only a single slice
plot_view(gdf, 
          hemi='left',
          side='medial',
          column='data2plot', 
          cmap='Reds', 
          show_cbar=True)
# Out:
# (<Figure size 500x500 with 2 Axes>, <Axes: >)

# %%
# the same goes for the famous aseg subcortical atlas and the classic

atlas_path = "../ggseg_py/atlases/aseg.rda"
gdf = rda2gpd(atlas_path, 'aseg')
plot_aseg(gdf)
# Out:
# (<Figure size 1000x500 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
# and the classic desikan killany

atlas_path = "../ggseg_py/atlases/dk.rda"
gdf = rda2gpd(atlas_path, 'dk')
plot_surface(gdf, show_cbar=False)
# Out:
# (<Figure size 700x500 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))
